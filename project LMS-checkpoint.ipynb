# %%
user={}
user['student1']={}
module={}
module['Fstudent']={}
def admin_session():
    while 1:
        print("Addmin Menu")
        print("1. Register new Student")
        print("2. Delete Existing Student")
        print("3. Logout")
        user_option = input(("select your option : "))
        user={}
        user['student1']={}
        if user_option == "1":
            print("")
            print("Register New Student")
            user['student1']['fullname'] = input(("Full Name : "))
            user['student1']['mobile'] = input(("Mobile No : "))
            user['student1']['email'] = input(("Email id : "))
            user['student1']['moduleid'] = input(("Module id : "))
            user['student1']['username'] = input(("Student username : "))
            user['student1']['password'] = input(("Student password : "))
            print(user['student1']['username'] + " has been registered as a student")
        elif user_option == "2":
            print("")
            print("Delete Existing Student Account")
            name = input(("Student username : "))
            if user['student1']['username'] == name:
                del user['student1']
            else:
                print("User not found")
            print(user['student1']['username'] + " has been deleted")
        elif user_option == "3":
            main()
        else:
            print("No valid option selected")
            
def Module():
    while 1:
        print("Modules")
        print("1.Create a new module")
        print("2.View all modules")
        print("3.View module details")
        print("4.Update module")
        print("5.Delete module")
        print("6. Back ")
        
        module={}
        module['Fstudent']={}
        user_option = input(("select your option : "))
        if user_option == "1":
            print("")
            print("Create a new module")
            module['Fstudent']['moduleid'] = input(("Module id : "))
            module['Fstudent']['modulename'] = input(("Module Name :"))
            module['Fstudent']['startdate'] = input(("start date YYYY-MM-DD :"))
            module['Fstudent']['enddate'] = input(("start date YYYY-MM-DD :"))
            module['Fstudent']['units'] = input(("Total Units No :"))
            module['Fstudent']['status'] =input(("Status of module Com,Pro :"))
            print(module['Fstudent']['modulename'] + " has been inserted")
        elif user_option == "2":
            print("")
            print("View all modules")
            print(module['Fstudent']['modulename'])
        elif user_option == "3":
            print("View module details")
            print()
            print(module['Fstudent'])
        elif user_option == "4":
            print("Update module")
            module['Fstudent']['startdate'] = input(("start date YYYY-MM-DD :"))
            module['Fstudent']['enddate'] = input(("start date YYYY-MM-DD :"))
            module['Fstudent']['units'] = input(("Total Units No :"))
            print("Module updated successfully")
        elif user_option == "5":
            print("Delete module")
            del module['Fstudent']
            print("Module deleted successfully")
            
        elif user_option == "6":
            main()
        else:
             print("No valid option selected")
             
def student_mod():
    while 1:
        print("Student menu")
        print("1.View Today's Schedule")
        print("2.View My Modules")
        print("3.Update Profile")
        print("4.Logout")
        user_option = input(("select your option : "))
        if user_option == "1":
            print("")
            print("View Today’s Schedule")
            
        elif user_option == "2":
            print("")
            print("View My Modules")
            print(module['Fstudent'])
        elif user_option == "3":
            print("")
            print("Update Profile")
            print("1. Change fullname")
            print("2.change Mobile No")
            print("3.change Email id")
            print("4.change Password")
            user_option = input(("select your option : "))
            if user_option == "1":
                print("")
                newfullname = input(("fullname : "))
                print("enter Your username")
                u = input(("username : "))
                if user['student1']['username'] == u:
                    user['student1']['fullname'] = newfullname
                    print("Changed fullname")
                else:
                    print("invalid username")
                
            elif user_option == "2":
                print("")
                mobileno = input(("Mobile No : "))
                print("enter Your username")
                us = input(("username : "))
                if user['student1']['username'] == us:
                    user['student1']['mobile'] = mobileno
                    print("changed Mobile No")
                else:
                    print("Invalid username")
            elif user_option == "3":
                print("")
                Emailid = input(("Eimailid : "))
                print("enter Your username")
                use = input(("username : "))
                if user['student1']['username'] == use:
                    user['student1']['email'] = Emailid
                    print("changed Emailid")
                else:
                    print("Invalid username")
            elif user_option == "4":
                print("")
                passw = input(("New password : "))
                print("enter Your username")
                usern = input(("username : "))
                if user['student1']['username'] == usern:
                    user['student1']['password'] = passw
                    print("changed password")
                else:
                    print("Invalid username")
            
        elif user_option == "4":
            main()
        else:
            print("No valid option selected")
def auth_admin():
    print("")
    print("Admin Login")
    print("")
    userna = input(("Username : "))
    passwo = input(("Password : "))
    if userna == "admin":
        if passwo == "admin":
            print("1.Student menu")
            print("2.modules menu")
            user_option = input(("Seelect your option : "))
            if user_option == "1":
                admin_session()
            elif user_option == "2":
                Module()
            else:
                print("Not Valid")
        else:
            print("Incorrect password !")
    else:
        print("Login details not recognised")
        
def student():
    print("")
    print("Student Login")
    print("")
    user = input(("Username : "))
    passwor = input(("Password : "))
    if user['student1']['username'] == user:
        if user['student1']['password'] == passwor:
            student_mod()
        else:
            print("Incorrect password !")
    else:
        print("Login details not recognised")   
        
def main():
    print("Welcome to the Edyoda Learning Management System \n")
    while 1:
        print("1. Login as Program Manager")
        print("2. Login as Student")
        print("3. End ")
        user_option = input(("Option : "))
        if user_option =="1":
            print("Program Manager Login")
            auth_admin()
        elif user_option == "2":
            print("Students Login")
            student()
        elif user_option == "3":
            main()
        else:
            print("Not Valid")
main()
# Out:
# Welcome to the Edyoda Learning Management System
#
# 1. Login as Program Manager
# 2. Login as Student
# 3. End
# Option : 1
# Program Manager Login
#
# Admin Login
#
# Username : admin
# Password : admin
# 1.Student menu
# 2.modules menu
# Seelect your option : 1
# Addmin Menu
# 1. Register new Student
# 2. Delete Existing Student
# 3. Logout
# select your option : 1
#
# Register New Student
# Full Name : rahul
# Mobile No : 1234567890
# Email id : rahul@gmail.com
# Module id : 12
# Student username : Rahul123
# Student password : 123456
# Rahul123 has been registered as a student
# Addmin Menu
# 1. Register new Student
# 2. Delete Existing Student
# 3. Logout
# select your option : 3
# Welcome to the Edyoda Learning Management System
#
# 1. Login as Program Manager
# 2. Login as Student
# 3. End
# Option : 1
# Program Manager Login
#
# Admin Login
#
# Username : admin
# Password : admin
# 1.Student menu
# 2.modules menu
# Seelect your option : 2
# Modules
# 1.Create a new module
# ...
